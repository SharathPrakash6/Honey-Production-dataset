# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Import required libraries and read the dataset

# %%
df1=pd.read_csv("honeyproduction.csv")
df1
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# 4     1361000.0  1998
# ..          ...   ...
# 621    618000.0  2012
# 622   6050000.0  2012
# 623    838000.0  2012
# 624   8487000.0  2012
# 625   4769000.0  2012
#
# [626 rows x 8 columns]

# %% [markdown]
# Check the first few samples, shape, info of the data and try to familiarize yourself with different features

# %%
df1.shape
df1.info
df1.isnull().sum()
# Out:
# state          0
# numcol         0
# yieldpercol    0
# totalprod      0
# stocks         0
# priceperlb     0
# prodvalue      0
# year           0
# dtype: int64

# %% [markdown]
# Display the percentage distribution of the data in each year using the pie chart

# %%
year_distribution = df1['year'].value_counts(normalize=True) * 100
plt.pie(year_distribution, labels=year_distribution.index, autopct='%1.1f%%', startangle=140);

# %% [markdown]
# Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings

# %%
sns.displot(df1['priceperlb'], kde=True, color='blue')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# * its skewed to the right
# * highest count is 100

# %% [markdown]
# Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings

# %%
sns.scatterplot(x='numcol', y='prodvalue', data=df1, color='blue')
# Out:
# <Axes: xlabel='numcol', ylabel='prodvalue'>

# %% [markdown]
# * when numcol increases prodvalue increases
# * highest numcol is areount 50000

# %% [markdown]
# Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings

# %%
sns.boxplot(x='year', y='prodvalue', data=df1, palette='viridis')
# Out:
# <Axes: xlabel='year', ylabel='prodvalue'>

# %% [markdown]
# the prodvalue is highest in the year 2010

# %% [markdown]
# Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year'

# %%
df1['year'].unique()
# Out:
# array([1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#        2009, 2010, 2011, 2012], dtype=int64)

# %%
cols = ['numcol', 'yieldpercol', 'totalprod', 'prodvalue','year']
sns.pairplot(df1[cols], corner = True, hue='year')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# * when year increase totalprod has increased
# *
# when year increases yieldpercol has increased

# %% [markdown]
# Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'stocks', 'price per lb', 'prodvalue'

# %%
cols = [ 'numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue']
sns.heatmap(df1[cols].corr(), annot = True)
# Out:
# <Axes: >

# %%
* highest correlation is totalprodXnumcol
* lowest correlation is priceperlbXnumcol
# Out:
#   Cell In[16], line 1
#     * highest correlation is totalprodXnumcol
#               ^
# SyntaxError: invalid syntax
